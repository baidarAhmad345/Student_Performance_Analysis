# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("student.csv")

# %%
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               30641 non-null  object
#  1   EthnicGroup          28801 non-null  object
#  2   ParentEduc           28796 non-null  object
#  3   LunchType            30641 non-null  object
#  4   TestPrep             28811 non-null  object
#  5   ParentMaritalStatus  29451 non-null  object
#  6   PracticeSport        30010 non-null  object
#  7   IsFirstChild         29737 non-null  object
#  8   NrSiblings           29069 non-null  float64
#  9   TransportMeans       27507 non-null  object
#  10  WklyStudyHours       29686 non-null  object
#  11  MathScore            30641 non-null  int64
#  12  ReadingScore         30641 non-null  int64
#  13  WritingScore         30641 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 3.3+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'EthnicGroup', 'ParentEduc', 'LunchType',
#        'TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild',
#        'NrSiblings', 'TransportMeans', 'WklyStudyHours', 'MathScore',
#        'ReadingScore', 'WritingScore'],
#       dtype='object')

# %%
df
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0      female         NaN   bachelor's degree      standard       none
# 1      female     group C        some college      standard        NaN
# 2      female     group B     master's degree      standard       none
# 3        male     group A  associate's degree  free/reduced       none
# 4        male     group C        some college      standard       none
# ...       ...         ...                 ...           ...        ...
# 30636  female     group D         high school      standard       none
# 30637    male     group E         high school      standard       none
# 30638  female         NaN         high school  free/reduced  completed
# 30639  female     group D  associate's degree      standard  completed
# 30640    male     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df.describe()
# Out:
#          NrSiblings     MathScore  ReadingScore  WritingScore
# count  29069.000000  30641.000000  30641.000000  30641.000000
# mean       2.145894     66.558402     69.377533     68.418622
# std        1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000     10.000000      4.000000
# 25%        1.000000     56.000000     59.000000     58.000000
# 50%        2.000000     67.000000     70.000000     69.000000
# 75%        3.000000     78.000000     80.000000     79.000000
# max        7.000000    100.000000    100.000000    100.000000

# %%
df.describe(include="object")
# Out:
#         Gender EthnicGroup    ParentEduc LunchType TestPrep  \
# count    30641       28801         28796     30641    28811
# unique       2           5             6         2        2
# top     female     group C  some college  standard     none
# freq     15424        9212          6633     19905    18856
#
#        ParentMaritalStatus PracticeSport IsFirstChild TransportMeans  \
# count                29451         30010        29737          27507
# unique                   4             3            2              2
# top                married     sometimes          yes     school_bus
# freq                 16844         15213        19082          16145
#
#        WklyStudyHours
# count           29686
# unique              3
# top            5 - 10
# freq            16246

# %%
df.isnull().sum()
# Out:
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df["WklyStudyHours"]=df["WklyStudyHours"].str.replace("05-Oct" , "5-10")

# %% [markdown]
# # EDA

# %% [markdown]
# # Gender Distribution

# %%
plt.figure(figsize=(7,5))
ax=sns.countplot(x="Gender" , data=df , hue="Gender")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %% [markdown]
# # Note: From the above, we can conclude that the number of females is greater than the number of males.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame setup for demonstration purposes
# df = pd.read_csv('your_data.csv')

# Group by 'LunchType' and calculate mean for each subject
gb2 = df.groupby("Gender").agg({
    "MathScore": "mean",
    "ReadingScore": "mean",
    "WritingScore": "mean"
}).reset_index()

# Melt the DataFrame to long format
gb2_melted = gb2.melt(id_vars="Gender", var_name="Subject", value_name="AverageScore")

# Pivot the data for heatmap
heatmap_data = gb2_melted.pivot(index="Gender", columns="Subject", values="AverageScore")

# Plot heatmap
plt.figure(figsize=(10, 6))
ax = sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Average Scores  by Gender")
plt.xlabel("Subject")
plt.ylabel("Gender")

plt.show()

# %% [markdown]
# # Note: From the graph, we can observe that males have higher scores in Math, but they score lower in Reading and Writing.

# %%
gb=df.groupby("ParentEduc").agg({"MathScore": "mean" , "ReadingScore":"mean" , "WritingScore":'mean'})

# %%
gb
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# associate's degree  68.365586     71.124324     70.299099
# bachelor's degree   70.466627     73.062020     73.331069
# high school         64.435731     67.213997     65.421136
# master's degree     72.336134     75.832921     76.356896
# some college        66.390472     69.179708     68.501432
# some high school    62.584013     65.510785     63.632409

# %%
sns.heatmap(gb , annot=True) 
plt.show()

# %% [markdown]
# # From the above chart it is clear that parent education is very important for child education

# %%
gb1=df.groupby("ParentMaritalStatus").agg({"MathScore": "mean" , "ReadingScore":"mean" , "WritingScore":'mean'})

# %%
gb1
# Out:
#                      MathScore  ReadingScore  WritingScore
# ParentMaritalStatus
# divorced             66.691197     69.655011     68.799146
# married              66.657326     69.389575     68.420981
# single               66.165704     69.157250     68.174440
# widowed              67.368866     69.651438     68.563452

# %%
sns.heatmap(gb1 , annot=True) 
plt.show()

# %% [markdown]
# # From the above chart it is clear that parent education is not important for child education

# %% [markdown]
# # Distribution of Ethnic Group

# %%
groupA=df.loc[(df["EthnicGroup"]=="group A")].count()
groupB=df.loc[(df["EthnicGroup"]=="group B")].count()
groupC=df.loc[(df["EthnicGroup"]=="group C")].count()
groupD=df.loc[(df["EthnicGroup"]=="group D")].count()
groupE=df.loc[(df["EthnicGroup"]=="group E")].count()
l=["group A" , "group B"  , "group C" , "group D" , "group E"]
list=[groupA["EthnicGroup"] , groupB["EthnicGroup"]  , groupC["EthnicGroup"] , groupD["EthnicGroup"] , groupE["EthnicGroup"]]
plt.pie(list , autopct='%1.1f%%' , labels=l)
plt.title('Distribution of Ethnic Groups')

plt.show()

# %% [markdown]
# # Lunch Type

# %%
gb2 = df.groupby("LunchType").agg({
    "MathScore": "mean",
    "ReadingScore": "mean",
    "WritingScore": "mean"
}).reset_index()

# Melt the DataFrame to long format
gb2_melted = gb2.melt(id_vars="LunchType", var_name="Subject", value_name="AverageScore")

# Plot using seaborn
plt.figure(figsize=(8, 6))
ax = sns.barplot(x="LunchType", y="AverageScore", hue="Subject", data=gb2_melted)

# Add labels to the bars
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', label_type='edge')

plt.title("Average Scores by Lunch Type")
plt.xlabel("Lunch Type")
plt.ylabel("Average Score")
plt.legend(title="Subject")
plt.legend(title="Subject", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame setup for demonstration purposes
# df = pd.read_csv('your_data.csv')

# Group by 'LunchType' and calculate mean for each subject
gb2 = df.groupby("LunchType").agg({
    "MathScore": "mean",
    "ReadingScore": "mean",
    "WritingScore": "mean"
}).reset_index()

# Melt the DataFrame to long format
gb2_melted = gb2.melt(id_vars="LunchType", var_name="Subject", value_name="AverageScore")

# Pivot the data for heatmap
heatmap_data = gb2_melted.pivot(index="LunchType", columns="Subject", values="AverageScore")

# Plot heatmap
plt.figure(figsize=(10, 6))
ax = sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Average Scores Heatmap by LunchType")
plt.xlabel("Subject")
plt.ylabel("LunchType")

plt.show()

# %% [markdown]
# # Note: From Above graph it is clear that lunch has impact on the student performance

# %% [markdown]
# # Test Preperation

# %%
gb2 = df.groupby("TestPrep").agg({
    "MathScore": "mean",
    "ReadingScore": "mean",
    "WritingScore": "mean"
}).reset_index()

# Melt the DataFrame to long format
gb2_melted = gb2.melt(id_vars="TestPrep", var_name="Subject", value_name="AverageScore")

# Plot using seaborn
plt.figure(figsize=(8, 6))
ax = sns.barplot(x="TestPrep", y="AverageScore", hue="Subject", data=gb2_melted)

# Add labels to the bars
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', label_type='edge')

plt.title("Average Scores by TestPrep")
plt.xlabel("Lunch Type")
plt.ylabel("Average Score")
plt.legend(title="Subject")
plt.legend(title="Subject", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame setup for demonstration purposes
# df = pd.read_csv('your_data.csv')

# Group by 'LunchType' and calculate mean for each subject
gb2 = df.groupby("TestPrep").agg({
    "MathScore": "mean",
    "ReadingScore": "mean",
    "WritingScore": "mean"
}).reset_index()

# Melt the DataFrame to long format
gb2_melted = gb2.melt(id_vars="TestPrep", var_name="Subject", value_name="AverageScore")

# Pivot the data for heatmap
heatmap_data = gb2_melted.pivot(index="TestPrep", columns="Subject", values="AverageScore")

# Plot heatmap
plt.figure(figsize=(10, 6))
ax = sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Average Scores  by TestPrep")
plt.xlabel("Subject")
plt.ylabel("TestPrep")

plt.show()

# %% [markdown]
# # Note: From Above graph it is clear that  preperation  has huge impact on the student performance

# %%
gb2 = df.groupby("PracticeSport").agg({
    "MathScore": "mean",
    "ReadingScore": "mean",
    "WritingScore": "mean"
}).reset_index()

# Melt the DataFrame to long format
gb2_melted = gb2.melt(id_vars="PracticeSport", var_name="Subject", value_name="AverageScore")

# Plot using seaborn
plt.figure(figsize=(8, 6))
ax = sns.barplot(x="PracticeSport", y="AverageScore", hue="Subject", data=gb2_melted)

# Add labels to the bars
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', label_type='edge')

plt.title("Average Scores by PracticeSport")
plt.xlabel("PracticeSport")
plt.ylabel("Average Score")
plt.legend(title="Subject")
plt.legend(title="Subject", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame setup for demonstration purposes
# df = pd.read_csv('your_data.csv')

# Group by 'LunchType' and calculate mean for each subject
gb2 = df.groupby("PracticeSport").agg({
    "MathScore": "mean",
    "ReadingScore": "mean",
    "WritingScore": "mean"
}).reset_index()

# Melt the DataFrame to long format
gb2_melted = gb2.melt(id_vars="PracticeSport", var_name="Subject", value_name="AverageScore")

# Pivot the data for heatmap
heatmap_data = gb2_melted.pivot(index="PracticeSport", columns="Subject", values="AverageScore")

# Plot heatmap
plt.figure(figsize=(10, 6))
ax = sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Average Scores  by PracticeSport")
plt.xlabel("Subject")
plt.ylabel("PracticeSport")

plt.show()

# %% [markdown]
# # From above graph it is clear sports has not so much impact on performance

# %% [markdown]
# # First Child

# %%
gb2 = df.groupby("IsFirstChild").agg({
    "MathScore": "mean",
    "ReadingScore": "mean",
    "WritingScore": "mean"
}).reset_index()

# Melt the DataFrame to long format
gb2_melted = gb2.melt(id_vars="IsFirstChild", var_name="Subject", value_name="AverageScore")

# Plot using seaborn
plt.figure(figsize=(8, 6))
ax = sns.barplot(x="IsFirstChild", y="AverageScore", hue="Subject", data=gb2_melted)

# Add labels to the bars
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', label_type='edge')

plt.title("Average Scores by IsFirstChild")
plt.xlabel("IsFirstChild")
plt.ylabel("Average Score")
plt.legend(title="Subject")
plt.legend(title="Subject", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# Note: From above graph it is clear first child or not  has no impact on performance

# %% [markdown]
# # Number of siblings

# %%
df["NrSiblings"].value_counts()
# Out:
# NrSiblings
# 1.0    8217
# 2.0    6790
# 3.0    6123
# 0.0    3085
# 4.0    2941
# 5.0    1320
# 6.0     302
# 7.0     291
# Name: count, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame setup for demonstration purposes
# df = pd.read_csv('your_data.csv')

# Group by 'LunchType' and calculate mean for each subject
gb2 = df.groupby("NrSiblings").agg({
    "MathScore": "mean",
    "ReadingScore": "mean",
    "WritingScore": "mean"
}).reset_index()

# Melt the DataFrame to long format
gb2_melted = gb2.melt(id_vars="NrSiblings", var_name="Subject", value_name="AverageScore")

# Pivot the data for heatmap
heatmap_data = gb2_melted.pivot(index="NrSiblings", columns="Subject", values="AverageScore")

# Plot heatmap
plt.figure(figsize=(10, 6))
ax = sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Average Scores  by NrSiblings")
plt.xlabel("Subject")
plt.ylabel("NrSiblings")

plt.show()

# %% [markdown]
# # Note: From above graph it is clear number of siblings   has no impact on performance of students

# %% [markdown]
# # TransportMeans

# %%
# Out:
# TransportMeans
# school_bus    16145
# private       11362
# Name: count, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame setup for demonstration purposes
# df = pd.read_csv('your_data.csv')

# Group by 'LunchType' and calculate mean for each subject
gb2 = df.groupby("TransportMeans").agg({
    "MathScore": "mean",
    "ReadingScore": "mean",
    "WritingScore": "mean"
}).reset_index()

# Melt the DataFrame to long format
gb2_melted = gb2.melt(id_vars="TransportMeans", var_name="Subject", value_name="AverageScore")

# Pivot the data for heatmap
heatmap_data = gb2_melted.pivot(index="TransportMeans", columns="Subject", values="AverageScore")

# Plot heatmap
plt.figure(figsize=(10, 6))
ax = sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Average Scores  by TransportMeans")
plt.xlabel("Subject")
plt.ylabel("TransportMeans")

plt.show()

# %% [markdown]
# # Note: From above graph it is clear transport has no impact on performance of students

# %% [markdown]
# # Weekely hours study

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame setup for demonstration purposes
# df = pd.read_csv('your_data.csv')

# Group by 'LunchType' and calculate mean for each subject
gb2 = df.groupby("WklyStudyHours").agg({
    "MathScore": "mean",
    "ReadingScore": "mean",
    "WritingScore": "mean"
}).reset_index()

# Melt the DataFrame to long format
gb2_melted = gb2.melt(id_vars="WklyStudyHours", var_name="Subject", value_name="AverageScore")

# Pivot the data for heatmap
heatmap_data = gb2_melted.pivot(index="WklyStudyHours", columns="Subject", values="AverageScore")

# Plot heatmap
plt.figure(figsize=(10, 6))
ax = sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Average Scores  by WklyStudyHours")
plt.xlabel("Subject")
plt.ylabel("WklyStudyHours")

plt.show()

# %% [markdown]
# # Note: From above graph it is clear more weekely  study  hours has impact on performance of students
